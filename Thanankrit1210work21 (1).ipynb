# %% [markdown]
# Thanakrit wiwitkul class5/12 Number10

# %%
print('Thanakrit')
print('class5/12')
print('Number10')
# Out:
# Thanakrit
# class5/12
# Number10

# %%
print("Thanakrit");
print("class5/12");
print("Number10");
# Out:
# Thanakrit
# class5/12
# Number10
